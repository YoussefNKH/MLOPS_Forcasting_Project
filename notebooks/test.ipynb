# %%
import pandas as pd
import pickle as pkl

# %%
# Allow unlimited columns and rows
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
# Optional: Set max column width to see full text content
pd.set_option('display.max_colwidth', None)

# %%
df=pkl.load(open("../data/CA_1_7.pkl","rb"))
df.head()
# Out:
# c:\Users\youss.YOUSSEF\OneDrive\Desktop\Nouveau dossier (6)\.venv\Lib\site-packages\pandas\io\formats\format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
#              id  item_id  dept_id  cat_id  store_id  state_id     d  sold  \
# 56711400  14370     1437        3       1         0         0  1861     1
# 56711401  14380     1438        3       1         0         0  1861     1
# 56711402  14390     1439        3       1         0         0  1861     0
# 56711403  14400     1440        3       1         0         0  1861     1
# 56711404  14410     1441        3       1         0         0  1861     0
#
#           wm_yr_wk  weekday  wday  month  year  event_name_1  event_type_1  \
# 56711400     11605        4     6      3  2016            -1            -1
# 56711401     11605        4     6      3  2016            -1            -1
# 56711402     11605        4     6      3  2016            -1            -1
# ...

# %%
df['sold'].head(100)
# Out:
# 56711400    1
# 56711401    1
# 56711402    0
# 56711403    1
# 56711404    0
# 56711405    2
# 56711406    1
# 56711407    0
# 56711408    0
# 56711409    0
# 56711410    0
# 56711411    0
# 56711412    1
# 56711413    3
# 56711414    2
# 56711415    9
# 56711416    1
# 56711417    0
# 56711418    0
# 56711419    0
# 56711420    1
# 56711421    0
# 56711422    0
# 56711423    0
# 56711424    1
# 56711425    0
# 56711426    0
# 56711427    0
# 56711428    0
# 56711429    1
# 56711430    0
# 56711431    1
# 56711432    0
# 56711433    1
# 56711434    0
# 56711435    1
# 56711436    1
# 56711437    1
# 56711438    0
# 56711439    0
# 56711440    0
# 56711441    0
# 56711442    8
# 56711443    0
# 56711444    0
# 56711445    1
# 56711446    0
# 56711447    9
# 56711448    1
# 56711449    2
# 56711450    0
# 56711451    0
# 56711452    0
# 56711453    1
# 56711454    0
# 56711455    0
# 56711456    1
# 56711457    0
# 56711458    0
# 56711459    0
# 56711460    0
# 56711461    0
# ...

# %%
columns_name=df.columns
print(columns_name)
# Out:
# Index(['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id', 'd',
#        'sold', 'wm_yr_wk', 'weekday', 'wday', 'month', 'year', 'event_name_1',
#        'event_type_1', 'event_name_2', 'event_type_2', 'snap_CA', 'snap_TX',
#        'snap_WI', 'sell_price', 'revenue', 'sold_lag_1', 'sold_lag_2',
#        'sold_lag_3', 'sold_lag_6', 'sold_lag_12', 'sold_lag_24', 'sold_lag_36',
#        'iteam_sold_avg', 'state_sold_avg', 'store_sold_avg', 'cat_sold_avg',
#        'dept_sold_avg', 'cat_dept_sold_avg', 'store_item_sold_avg',
#        'cat_item_sold_avg', 'dept_item_sold_avg', 'state_store_sold_avg',
#        'state_store_cat_sold_avg', 'store_cat_dept_sold_avg',
#        'rolling_sold_mean', 'expanding_sold_mean', 'selling_trend'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 182940 entries, 56711400 to 58513358
# Data columns (total 44 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   id                        182940 non-null  int16
#  1   item_id                   182940 non-null  int16
#  2   dept_id                   182940 non-null  int8
#  3   cat_id                    182940 non-null  int8
#  4   store_id                  182940 non-null  int8
#  5   state_id                  182940 non-null  int8
#  6   d                         182940 non-null  int16
#  7   sold                      182940 non-null  int16
#  8   wm_yr_wk                  182940 non-null  int16
#  9   weekday                   182940 non-null  int8
#  10  wday                      182940 non-null  int8
#  11  month                     182940 non-null  int8
#  12  year                      182940 non-null  int16
# ...

# %%
df.drop('sold',axis=1,inplace=True)
df
df.to_csv('../data/CA_1_0.csv',index=False,header=True)
